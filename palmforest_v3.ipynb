# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow.python as tf
import sklearn
import scipy

# %matplotlib inline

# %% [markdown]
# Data Loading

# %%
agrolimate_csv = './POWER_Regional_monthly_1981_2020_000d9857S_002d4905N_100d0750E_103d7500E_LST.csv'
prod_qty_csv = './FAOSTAT_data_prodQTY.csv'
yield_csv = './FAOSTAT_data_panen.csv'
harvested_csv = './FAOSTAT_data_area_harvested.csv'

# %% [markdown]
# AGROCLIMATE DATA
#
# NASA/POWER CERES/MERRA2 Native Resolution Monthly and Annual
# Dates (month/day/year): 01/01/1981 through 12/31/2020
# Location: Regional
# Elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = na meters
# The value for missing source data that cannot be computed or is outside of the sources availability range: -999
# Parameter(s):
# 1. TS                   : MERRA-2 Earth Skin Temperature (C)
# 2. T2M                  : MERRA-2 Temperature at 2 Meters (C)
# 3. QV2M                 : MERRA-2 Specific Humidity at 2 Meters (g/kg)
# 4. RH2M                 : MERRA-2 Relative Humidity at 2 Meters (%)
# 5. T2MDEW               : MERRA-2 Dew/Frost Point at 2 Meters (C)
# 6. T2MWET               : MERRA-2 Wet Bulb Temperature at 2 Meters (C)
# 7. GWETTOP              : MERRA-2 Surface Soil Wetness (1)
# 8. T2M_MAX              : MERRA-2 Temperature at 2 Meters Maximum (C)
# 9. T2M_MIN              : MERRA-2 Temperature at 2 Meters Minimum (C)
# 10. GWETPROF            : MERRA-2 Profile Soil Moisture (1)
# 11. GWETROOT            : MERRA-2 Root Zone Soil Wetness (1)
# 12. T2M_RANGE           : MERRA-2 Temperature at 2 Meters Range (C)
# 13. PRECTOTCORR         : MERRA-2 Precipitation Corrected (mm/day)
# 14. PRECTOTCORR_SUM     : MERRA-2 Precipitation Corrected Sum (mm)
# 15. ALLSKY_SFC_LW_DWN   : CERES SYN1deg All Sky Surface Longwave Downward Irradiance (W/m^2)
#
# FAOSTAT DATA
#
# 1.	Domain Code		        : Kode domain data.
# 2.	Domain			        : Nama domain data.
# 3.	Area Code (M49)	        :  Kode area.
# 4.	Area			        : Nama Negara.
# 5.	Element Code		    : Kode element.
# 6.	Element		            : Komponen, Area Harvested.
# 7.	Item Code (CPC)	        : Kode produk.
# 8.	Item			        : Nama jenis produk.
# 9.	Year Code		        : Kode tahun.
# 10.	Year			        : Tahun.
# 11.	Unit			        : Satuan unit, Ha (hektar).
# 12.	Value			        : Nilai data.
# 13.	Flag			        : Binary (E/A)
# 14.	Flag Description		: Deskripsi Flag. E = Estimated Value, A = Official Figure

# %%
# Reading dataset from source

from pandas import read_csv

agrolimate_data = read_csv(agrolimate_csv)
prod_qty_data = read_csv(prod_qty_csv)
yield_data = read_csv(yield_csv)
harvested_data = read_csv(harvested_csv)

# %%
# Creating Dataframe

agrolimate_df = pd.DataFrame(agrolimate_data)
prod_qty_df = pd.DataFrame(prod_qty_data)
yield_df = pd.DataFrame(yield_data)
harvested_df = pd.DataFrame(harvested_data)

# %% [markdown]
# Droping unnececary column

# %%
prod_qty_df = prod_qty_df.filter(['Production Quantity'])
yield_df = yield_df.filter(['Crop Yield'])
harvested_df = harvested_df.filter(['Harvested Area'])
agrolimate_df = agrolimate_df.filter(['PARAMETER', 'YEAR', 'LAT', 'LON', 'ANN'])

# %%
# separating agroclimate data based on parameter
# this code is stupid better loop this instead doing one by one - m1
# idc you do that instead - m2

TS_df = agrolimate_df.loc[agrolimate_df['PARAMETER'] == 'TS'].reset_index(drop=True)
T2M_df = agrolimate_df.loc[agrolimate_df['PARAMETER'] == 'T2M'].reset_index(drop=True)
QV2M_df = agrolimate_df.loc[agrolimate_df['PARAMETER'] == 'QV2M'].reset_index(drop=True)
RH2M_df = agrolimate_df.loc[agrolimate_df['PARAMETER'] == 'RH2M'].reset_index(drop=True)
T2MDEW_df = agrolimate_df.loc[agrolimate_df['PARAMETER'] == 'T2MDEW'].reset_index(drop=True)
T2MWET_df = agrolimate_df.loc[agrolimate_df['PARAMETER'] == 'T2MWET'].reset_index(drop=True)
GWETTOP_df = agrolimate_df.loc[agrolimate_df['PARAMETER'] == 'GWETTOP'].reset_index(drop=True)
T2M_MAX_df = agrolimate_df.loc[agrolimate_df['PARAMETER'] == 'T2M_MAX'].reset_index(drop=True)
T2M_MIN_df = agrolimate_df.loc[agrolimate_df['PARAMETER'] == 'T2M_MIN'].reset_index(drop=True)
GWETPROF_df = agrolimate_df.loc[agrolimate_df['PARAMETER'] == 'GWETPROF'].reset_index(drop=True)
GWETROOT_df = agrolimate_df.loc[agrolimate_df['PARAMETER'] == 'GWETROOT'].reset_index(drop=True)
T2M_RANGE_df = agrolimate_df.loc[agrolimate_df['PARAMETER'] == 'T2M_RANGE'].reset_index(drop=True)
PRECTOTCORR_df = agrolimate_df.loc[agrolimate_df['PARAMETER'] == 'PRECTOTCORR'].reset_index(drop=True)
PRECTOTCORR_SUM_df = agrolimate_df.loc[agrolimate_df['PARAMETER'] == 'PRECTOTCORR_SUM'].reset_index(drop=True)
ALLSKY_SFC_LW_DWN_df = agrolimate_df.loc[agrolimate_df['PARAMETER'] == 'ALLSKY_SFC_LW_DWN'].reset_index(drop=True)

# %%
# create mean data for all longitude and latitude based on year
# this code is stupid better loop this instead doing one by one - m1
# idc you do that instead - m2

new_TS_df = pd.DataFrame(TS_df.groupby('YEAR').mean()['ANN'])
new_TS_df = new_TS_df.rename(columns={'ANN': 'TS'})
new_TS_df = new_TS_df.reset_index(drop=True)

new_T2M_df = pd.DataFrame(T2M_df.groupby('YEAR').mean()['ANN'])
new_T2M_df = new_T2M_df.rename(columns={'ANN': 'T2M'})
new_T2M_df = new_T2M_df.reset_index(drop=True)

new_QV2M_df = pd.DataFrame(QV2M_df.groupby('YEAR').mean()['ANN'])
new_QV2M_df = new_QV2M_df.rename(columns={'ANN': 'QV2M'})
new_QV2M_df = new_QV2M_df.reset_index(drop=True)

new_RH2M_df = pd.DataFrame(RH2M_df.groupby('YEAR').mean()['ANN'])
new_RH2M_df = new_RH2M_df.rename(columns={'ANN': 'RH2M'})
new_RH2M_df = new_RH2M_df.reset_index(drop=True)

new_T2MDEW_df = pd.DataFrame(T2MDEW_df.groupby('YEAR').mean()['ANN'])
new_T2MDEW_df = new_T2MDEW_df.rename(columns={'ANN': 'T2MDEW'})
new_T2MDEW_df = new_T2MDEW_df.reset_index(drop=True)

new_T2MWET_df = pd.DataFrame(T2MWET_df.groupby('YEAR').mean()['ANN'])
new_T2MWET_df = new_T2MWET_df.rename(columns={'ANN': 'T2MWET'})
new_T2MWET_df = new_T2MWET_df.reset_index(drop=True)

new_GWETTOP_df = pd.DataFrame(GWETTOP_df.groupby('YEAR').mean()['ANN'])
new_GWETTOP_df = new_GWETTOP_df.rename(columns={'ANN': 'GWETTOP'})
new_GWETTOP_df = new_GWETTOP_df.reset_index(drop=True)

new_T2M_MAX_df = pd.DataFrame(T2M_MAX_df.groupby('YEAR').mean()['ANN'])
new_T2M_MAX_df = new_T2M_MAX_df.rename(columns={'ANN': 'T2M_MAX'})
new_T2M_MAX_df = new_T2M_MAX_df.reset_index(drop=True)

new_T2M_MIN_df = pd.DataFrame(T2M_MIN_df.groupby('YEAR').mean()['ANN'])
new_T2M_MIN_df = new_T2M_MIN_df.rename(columns={'ANN': 'T2M_MIN'})
new_T2M_MIN_df = new_T2M_MIN_df.reset_index(drop=True)

new_GWETPROF_df = pd.DataFrame(GWETPROF_df.groupby('YEAR').mean()['ANN'])
new_GWETPROF_df = new_GWETPROF_df.rename(columns={'ANN': 'GWETPROF'})
new_GWETPROF_df = new_GWETPROF_df.reset_index(drop=True)

new_GWETROOT_df = pd.DataFrame(GWETROOT_df.groupby('YEAR').mean()['ANN'])
new_GWETROOT_df = new_GWETROOT_df.rename(columns={'ANN': 'GWETROOT'})
new_GWETROOT_df = new_GWETROOT_df.reset_index(drop=True)

new_T2M_RANGE_df = pd.DataFrame(T2M_RANGE_df.groupby('YEAR').mean()['ANN'])
new_T2M_RANGE_df = new_T2M_RANGE_df.rename(columns={'ANN': 'T2M_RANGE'})
new_T2M_RANGE_df = new_T2M_RANGE_df.reset_index(drop=True)

new_PRECTOTCORR_df = pd.DataFrame(PRECTOTCORR_df.groupby('YEAR').mean()['ANN'])
new_PRECTOTCORR_df = new_PRECTOTCORR_df.rename(columns={'ANN': 'PRECTOTCORR'})
new_PRECTOTCORR_df = new_PRECTOTCORR_df.reset_index(drop=True)

new_PRECTOTCORR_SUM_df = pd.DataFrame(PRECTOTCORR_SUM_df.groupby('YEAR').mean()['ANN'])
new_PRECTOTCORR_SUM_df = new_PRECTOTCORR_SUM_df.rename(columns={'ANN': 'PRECTOTCORR_SUM'})
new_PRECTOTCORR_SUM_df = new_PRECTOTCORR_SUM_df.reset_index(drop=True)

new_ALLSKY_SFC_LW_DWN_df = pd.DataFrame(ALLSKY_SFC_LW_DWN_df.groupby('YEAR').mean()['ANN'])
new_ALLSKY_SFC_LW_DWN_df = new_ALLSKY_SFC_LW_DWN_df.rename(columns={'ANN': 'ALLSKY_SFC_LW_DWN'})
new_ALLSKY_SFC_LW_DWN_df = new_ALLSKY_SFC_LW_DWN_df.reset_index(drop=True)
# Out:
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2686441713.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new_TS_df = pd.DataFrame(TS_df.groupby('YEAR').mean()['ANN'])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2686441713.py:9: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new_T2M_df = pd.DataFrame(T2M_df.groupby('YEAR').mean()['ANN'])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2686441713.py:13: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new_QV2M_df = pd.DataFrame(QV2M_df.groupby('YEAR').mean()['ANN'])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2686441713.py:17: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new_RH2M_df = pd.DataFrame(RH2M_df.groupby('YEAR').mean()['ANN'])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2686441713.py:21: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new_T2MDEW_df = pd.DataFrame(T2MDEW_df.groupby('YEAR').mean()['ANN'])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2686441713.py:25: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new_T2MWET_df = pd.DataFrame(T2MWET_df.groupby('YEAR').mean()['ANN'])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2686441713.py:29: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new_GWETTOP_df = pd.DataFrame(GWETTOP_df.groupby('YEAR').mean()['ANN'])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2686441713.py:33: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new_T2M_MAX_df = pd.DataFrame(T2M_MAX_df.groupby('YEAR').mean()['ANN'])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2686441713.py:37: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new_T2M_MIN_df = pd.DataFrame(T2M_MIN_df.groupby('YEAR').mean()['ANN'])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2686441713.py:41: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new_GWETPROF_df = pd.DataFrame(GWETPROF_df.groupby('YEAR').mean()['ANN'])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2686441713.py:45: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new_GWETROOT_df = pd.DataFrame(GWETROOT_df.groupby('YEAR').mean()['ANN'])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2686441713.py:49: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new_T2M_RANGE_df = pd.DataFrame(T2M_RANGE_df.groupby('YEAR').mean()['ANN'])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2686441713.py:53: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new_PRECTOTCORR_df = pd.DataFrame(PRECTOTCORR_df.groupby('YEAR').mean()['ANN'])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2686441713.py:57: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new_PRECTOTCORR_SUM_df = pd.DataFrame(PRECTOTCORR_SUM_df.groupby('YEAR').mean()['ANN'])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2686441713.py:61: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new_ALLSKY_SFC_LW_DWN_df = pd.DataFrame(ALLSKY_SFC_LW_DWN_df.groupby('YEAR').mean()['ANN'])

# %% [markdown]
# Merge Dataframes into one Dataframe

# %%
# merginr newly created agroclimate data frame

agroclimate_merge = [
    new_TS_df,
    new_T2M_df,
    new_QV2M_df,
    new_RH2M_df,
    new_T2MDEW_df,
    new_T2MWET_df,
    new_GWETTOP_df,
    new_T2M_MAX_df,
    new_T2M_MIN_df,
    new_GWETPROF_df,
    new_GWETROOT_df,
    new_T2M_RANGE_df,
    new_PRECTOTCORR_df,
    new_PRECTOTCORR_SUM_df,
    new_ALLSKY_SFC_LW_DWN_df
]

new_agroclimate_df = pd.concat(agroclimate_merge, axis=1)

# %%
merge = [new_agroclimate_df, prod_qty_df, harvested_df, yield_df]

data = pd.concat(merge, axis=1)

# %%
data.sample(20)
# Out:
#            TS        T2M       QV2M       RH2M     T2MDEW     T2MWET  \
# 9   26.548750  26.243214  18.238393  85.483571  23.493393  24.868214
# 28  26.429286  26.230357  18.607143  87.021964  23.808393  25.018929
# 2   26.578393  26.252321  18.164821  85.166607  23.427857  24.839643
# 15  26.228214  25.951964  18.398750  87.447857  23.616071  24.783571
# 14  26.351250  26.092857  18.716429  88.182679  23.905536  24.999464
# 32  26.462143  26.289643  18.578929  86.635357  23.781964  25.036429
# 38  26.967143  26.764107  18.855893  85.678750  24.037321  25.400536
# 0   26.336964  26.012679  18.014464  85.571071  23.285536  24.648929
# 37  26.554107  26.350893  18.667679  86.757679  23.867143  25.109286
# 5   26.003929  25.728393  17.918393  86.477500  23.198214  24.464107
# 10  26.332679  26.056250  18.313393  86.685536  23.555893  24.806250
# 39  26.822679  26.580714  18.927143  86.796250  24.095714  25.338929
# 17  27.016964  26.711429  19.173929  87.170893  24.301429  25.506786
# 26  26.318571  26.061607  18.603929  87.822143  23.803036  24.932321
# 6   26.418571  26.112857  18.322857  86.472679  23.570714  24.841071
# 3   25.818393  25.514821  17.748393  86.702500  23.033393  24.274821
# 27  26.209286  25.986964  18.498214  87.755179  23.714464  24.850179
# 31  26.400893  26.224821  18.527321  86.728036  23.739464  24.981429
# 25  26.361429  26.128929  18.622321  87.640893  23.832679  24.981429
# 1   26.297321  25.960000  17.834643  85.045714  23.118571  24.540179
#
#      GWETTOP    T2M_MAX    T2M_MIN  GWETPROF  GWETROOT  T2M_RANGE  \
# 9   0.743571  31.757500  21.781071  0.769821  0.728571   9.976607
# 28  0.886429  31.211071  21.858571  0.926786  0.908393   9.353036
# 2   0.810000  32.058750  21.546964  0.846429  0.808571  10.510536
# 15  0.871786  31.112143  21.339643  0.912321  0.890179   9.772857
# 14  0.897857  30.930000  21.866964  0.933750  0.922679   9.063036
# 32  0.894286  31.430179  21.938393  0.934643  0.918750   9.492857
# 38  0.817143  31.903393  21.805000  0.855357  0.821786  10.097321
# 0   0.848214  31.213036  21.491786  0.887857  0.860179   9.721071
# 37  0.883750  31.423571  21.045357  0.922679  0.905000  10.376786
# 5   0.869286  30.696250  21.236607  0.906786  0.886071   9.459821
# 10  0.785000  31.127143  21.315536  0.813571  0.778393   9.811250
# 39  0.852143  31.776607  22.499464  0.889643  0.865357   9.277679
# 17  0.848571  32.128571  22.538393  0.883929  0.858571   9.590357
# 26  0.907143  30.929107  21.296607  0.946964  0.938571   9.632857
# 6   0.839286  31.204107  21.459821  0.877143  0.843929   9.742857
# 3   0.885536  30.475536  21.325000  0.927857  0.910536   9.151071
# 27  0.907500  31.060714  22.078750  0.947857  0.939821   8.980893
# 31  0.889286  31.211429  21.967679  0.930179  0.915000   9.243036
# 25  0.886071  31.033393  21.860893  0.926786  0.910179   9.172679
# 1   0.767500  31.335893  20.855714  0.800000  0.760179  10.480714
#
#     PRECTOTCORR  PRECTOTCORR_SUM  ALLSKY_SFC_LW_DWN  Production Quantity  \
# 9      4.803393      1662.968929         421.720714             11151795
# 28     7.553214      2691.289643         417.351786             90000000
# 2      6.065536      2130.430893        -999.000000              4600000
# 15     6.700714      2369.798036         420.872143             24490000
# 14     8.430000      2992.355179         422.590357             22400000
# 32     7.648393      2730.566429         416.012857            180068301
# 38     5.966071      2100.070714         419.769643            250256133
# 0      6.850536      2422.900179        -999.000000              3800000
# 37     7.344286      2614.748929         416.524286            246207981
# 5      7.611786      2708.353214         268.930357              7725000
# 10     5.782857      2029.642857         422.959643             12153216
# 39     7.487143      2668.312143         419.617143            256528600
# 17     7.313571      2578.513214         424.791071             29510000
# 26     7.941786      2833.342857         417.440000             78000000
# 6      6.135000      2146.533036         269.446429              8859147
# 3      7.489286      2653.480536         271.838214              6280000
# 27     7.742321      2774.657679         415.910357             85000000
# 31     7.262143      2589.973393         416.064643            165466793
# 25     7.338393      2587.778929         417.852500             80250000
# 1      5.521607      1935.285714        -999.000000              4300000
#
#     Harvested Area  Crop Yield
# 9           673033      165695
# 28         5370000      167598
# 2           255300      180180
# 15         1428350      171457
# 14         1190000      188235
# 32        10465020      172067
# 38        14595579      171460
# 0           230000      165217
# 37        14326350      171857
# 5           374100      206496
# 10          772245      157375
# 39        14996010      171065
# 17         1795081      164394
# 26         4560000      171053
# 6           421600      210132
# 3           296300      211947
# 27         4980000      170683
# 31         9572715      172853
# 25         4110000      195255
# 1           239700      179391

# %% [markdown]
# Exploratory Data Analysis & Preprocessing

# %%
# checking mising value

data.isnull().sum()
# Out:
# TS                     0
# T2M                    0
# QV2M                   0
# RH2M                   0
# T2MDEW                 0
# T2MWET                 0
# GWETTOP                0
# T2M_MAX                0
# T2M_MIN                0
# GWETPROF               0
# GWETROOT               0
# T2M_RANGE              0
# PRECTOTCORR            0
# PRECTOTCORR_SUM        0
# ALLSKY_SFC_LW_DWN      0
# Production Quantity    0
# Harvested Area         0
# Crop Yield             0
# dtype: int64

# %%
# Checking duplicated data

print(f'Duplicated data in data frame: {data.duplicated().sum()}')
# Out:
# Duplicated data in data frame: 0

# %%
# checking data info

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   TS                   40 non-null     float64
#  1   T2M                  40 non-null     float64
#  2   QV2M                 40 non-null     float64
#  3   RH2M                 40 non-null     float64
#  4   T2MDEW               40 non-null     float64
#  5   T2MWET               40 non-null     float64
#  6   GWETTOP              40 non-null     float64
#  7   T2M_MAX              40 non-null     float64
#  8   T2M_MIN              40 non-null     float64
#  9   GWETPROF             40 non-null     float64
#  10  GWETROOT             40 non-null     float64
#  11  T2M_RANGE            40 non-null     float64
#  12  PRECTOTCORR          40 non-null     float64
#  13  PRECTOTCORR_SUM      40 non-null     float64
#  14  ALLSKY_SFC_LW_DWN    40 non-null     float64
#  15  Production Quantity  40 non-null     int64
#  16  Harvested Area       40 non-null     int64
#  17  Crop Yield           40 non-null     int64
# dtypes: float64(15), int64(3)
# memory usage: 5.8 KB

# %%
data.describe()
# Out:
#               TS        T2M       QV2M       RH2M     T2MDEW     T2MWET  \
# count  40.000000  40.000000  40.000000  40.000000  40.000000  40.000000
# mean   26.420250  26.160643  18.466513  86.795384  23.685897  24.923406
# std     0.241280   0.258844   0.315319   0.766211   0.281407   0.257911
# min    25.818393  25.514821  17.731250  85.045714  23.017679  24.274821
# 25%    26.294375  26.011920  18.361696  86.440848  23.596563  24.825536
# 50%    26.400536  26.139018  18.529018  86.787054  23.737946  24.925804
# 75%    26.555045  26.275714  18.653482  87.426295  23.859643  25.040402
# max    27.016964  26.764107  19.173929  88.182679  24.301429  25.506786
#
#          GWETTOP    T2M_MAX    T2M_MIN   GWETPROF   GWETROOT  T2M_RANGE  \
# count  40.000000  40.000000  40.000000  40.000000  40.000000  40.000000
# mean    0.858982  31.260009  21.661129   0.897170   0.874076   9.598754
# std     0.040509   0.382600   0.370473   0.042967   0.052303   0.413784
# min     0.743571  30.475536  20.855714   0.769821   0.728571   8.902857
# 25%     0.837768  31.000312  21.429777   0.875580   0.842500   9.250000
# 50%     0.869375  31.211250  21.659821   0.909196   0.885804   9.595179
# 75%     0.886429  31.437366  21.859152   0.927946   0.910268   9.812455
# max     0.911964  32.128571  22.538393   0.951071   0.945714  10.510536
#
#        PRECTOTCORR  PRECTOTCORR_SUM  ALLSKY_SFC_LW_DWN  Production Quantity  \
# count    40.000000        40.000000          40.000000         4.000000e+01
# mean      6.944219      2458.534246         298.059661         7.791797e+07
# std       0.973859       361.065071         376.787881         8.229456e+07
# min       4.719643      1636.752857        -999.000000         3.800000e+06
# 25%       6.188170      2184.479018         416.051696         1.190286e+07
# 50%       7.230536      2555.870446         418.744643         3.866500e+07
# 75%       7.487679      2665.387946         420.906161         1.481071e+08
# max       8.704464      3114.615000         424.791071         2.565286e+08
#
#        Harvested Area     Crop Yield
# count    4.000000e+01      40.000000
# mean     4.483448e+06  178114.475000
# std      4.801609e+06   13845.334558
# min      2.300000e+05  151349.000000
# 25%      7.474420e+05  170960.500000
# 50%      2.107000e+06  172906.500000
# 75%      8.537252e+06  185866.000000
# max      1.499601e+07  211947.000000

# %%
# checking the outliers

fig, axs = plt.subplots(ncols=9, nrows=2, figsize=(20, 10))
index=0
axs = axs.flatten()

for k, v in data.items():
    sns.boxplot(y=k, data=data, ax=axs[index])
    index+=1

plt.tight_layout()

# %%
# checking outlier percentage

for k, v in data.items():
    q1 = v.quantile(0.25)
    q3 = v.quantile(0.75)
    irq = q3 - q1

    v_col = v[(v <= q1 - 1.5 * irq) | (v >= q3 + 1.5 * irq)]
    perc = np.shape(v_col)[0] * 100.0 / np.shape(data)[0]

    print('Column {} Outliers {:.2f}%'.format(k, perc))
# Out:
# Column TS Outliers 7.50%
# Column T2M Outliers 7.50%
# Column QV2M Outliers 12.50%
# Column RH2M Outliers 0.00%
# Column T2MDEW Outliers 12.50%
# Column T2MWET Outliers 15.00%
# Column GWETTOP Outliers 2.50%
# Column T2M_MAX Outliers 2.50%
# Column T2M_MIN Outliers 2.50%
# Column GWETPROF Outliers 2.50%
# Column GWETROOT Outliers 2.50%
# Column T2M_RANGE Outliers 0.00%
# Column PRECTOTCORR Outliers 0.00%
# Column PRECTOTCORR_SUM Outliers 0.00%
# Column ALLSKY_SFC_LW_DWN Outliers 17.50%
# Column Production Quantity Outliers 0.00%
# Column Harvested Area Outliers 0.00%
# Column Crop Yield Outliers 5.00%

# %%
fig, axs = plt.subplots(ncols=6, nrows=3, figsize=(20,10))
index = 0
axs = axs.flatten()

for k, v in data.items():
  sns.distplot(v, ax=axs[index])
  index += 1

plt.tight_layout()
# Out:
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2461719023.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2461719023.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2461719023.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2461719023.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2461719023.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2461719023.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2461719023.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2461719023.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2461719023.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2461719023.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2461719023.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2461719023.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2461719023.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2461719023.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2461719023.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2461719023.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2461719023.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\2461719023.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v, ax=axs[index])

# %%
data = data.drop(columns=['ALLSKY_SFC_LW_DWN'])

# %%
# checking skewness & kurtosis

index = 0

for k, v in data.items():
  print('Feature {} Skewness = {:.7f}'.format(k, data[k].skew()))
  print('Feature {} Kurtosis = {:.7f}'.format(k, data[k].kurt()))
  index += 1
# Out:
# Feature TS Skewness = 0.3358891
# Feature TS Kurtosis = 1.0478877
# Feature T2M Skewness = 0.2459337
# Feature T2M Kurtosis = 0.7178776
# Feature QV2M Skewness = -0.5870545
# Feature QV2M Kurtosis = 0.5866817
# Feature RH2M Skewness = -0.5607859
# Feature RH2M Kurtosis = -0.2270219
# Feature T2MDEW Skewness = -0.6424421
# Feature T2MDEW Kurtosis = 0.6390332
# Feature T2MWET Skewness = -0.1940609
# Feature T2MWET Kurtosis = 0.7846102
# Feature GWETTOP Skewness = -1.0082362
# Feature GWETTOP Kurtosis = 0.6495494
# Feature T2M_MAX Skewness = 0.4645560
# Feature T2M_MAX Kurtosis = -0.1361596
# Feature T2M_MIN Skewness = 0.3136481
# Feature T2M_MIN Kurtosis = 0.2762727
# Feature GWETPROF Skewness = -1.1291623
# Feature GWETPROF Kurtosis = 0.9822247
# Feature GWETROOT Skewness = -0.9150779
# Feature GWETROOT Kurtosis = 0.4161550
# Feature T2M_RANGE Skewness = 0.5254863
# Feature T2M_RANGE Kurtosis = -0.1805305
# Feature PRECTOTCORR Skewness = -0.4187163
# Feature PRECTOTCORR Kurtosis = -0.1455802
# Feature PRECTOTCORR_SUM Skewness = -0.4178717
# Feature PRECTOTCORR_SUM Kurtosis = -0.1591437
# Feature Production Quantity Skewness = 1.0180806
# Feature Production Quantity Kurtosis = -0.3602914
# Feature Harvested Area Skewness = 1.0372881
# Feature Harvested Area Kurtosis = -0.3301591
# Feature Crop Yield Skewness = 0.8808899
# Feature Crop Yield Kurtosis = 0.4753633

# %%
# Checking distribution of data

from scipy import stats
from scipy.stats import norm, skew

fig, axs = plt.subplots()
index = 0

data = np.log1p(data)

for k, v in data.items():
  sns.distplot(data[k], fit=norm)

  (mu, sigma) = norm.fit(data[k])
  print('\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

  plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f})'.format(mu, sigma)], loc='best')

  fig = plt.figure()
  res = stats.probplot(data[k], plot=plt)
  plt.xlabel('{} Theoritical Quantiles'.format(k))
  plt.show()

  index += 1

plt.tight_layout()
# Out:
#  mu = 3.31 and sigma = 0.01
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\719428479.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[k], fit=norm)
#  mu = 3.30 and sigma = 0.01
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\719428479.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[k], fit=norm)
#  mu = 2.97 and sigma = 0.02
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\719428479.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[k], fit=norm)
#  mu = 4.47 and sigma = 0.01
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\719428479.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[k], fit=norm)
#  mu = 3.21 and sigma = 0.01
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\719428479.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[k], fit=norm)
#  mu = 3.26 and sigma = 0.01
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\719428479.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[k], fit=norm)
#  mu = 0.62 and sigma = 0.02
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\719428479.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[k], fit=norm)
#  mu = 3.47 and sigma = 0.01
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\719428479.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[k], fit=norm)
#  mu = 3.12 and sigma = 0.02
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\719428479.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[k], fit=norm)
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\719428479.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[k], fit=norm)
#  mu = 0.64 and sigma = 0.02
#  mu = 0.63 and sigma = 0.03
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\719428479.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[k], fit=norm)
#  mu = 2.36 and sigma = 0.04
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\719428479.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[k], fit=norm)
#  mu = 2.06 and sigma = 0.13
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\719428479.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[k], fit=norm)
#  mu = 7.80 and sigma = 0.15
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\719428479.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[k], fit=norm)
#  mu = 17.47 and sigma = 1.30
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\719428479.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[k], fit=norm)
#  mu = 14.59 and sigma = 1.32
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\719428479.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[k], fit=norm)
#  mu = 12.09 and sigma = 0.07
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\719428479.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[k], fit=norm)

# %% [markdown]
# Removing Feature
# - ALLSKY_SFC_LW_DWN
#
# Normalizing Data
# - Crop Yield
# - Production Quantity
# - Harvested Area

# %%
# checking correlation between feature with heatmap

plt.figure(figsize=(20, 10))

cor = data.corr().abs()
sns.heatmap(cor, annot=True)
plt.show()

# %%
# only using certain feature with ammount of correlation

cor_target = abs(cor['Crop Yield'])
relevant_features = cor_target[cor_target > 0.2]
feature_names = [index for index, value in relevant_features.iteritems()]

feature_names.remove('Crop Yield')

print(feature_names)
print(len(feature_names))
# Out:
# ['TS', 'T2M', 'QV2M', 'T2MDEW', 'T2MWET', 'GWETTOP', 'T2M_MAX', 'GWETPROF', 'GWETROOT', 'T2M_RANGE', 'Production Quantity', 'Harvested Area']
# 12
# C:\Users\malik\AppData\Local\Temp\ipykernel_2856\1477983373.py:5: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   feature_names = [index for index, value in relevant_features.iteritems()]

# %%
from sklearn import preprocessing

min_max_scaller = preprocessing.MinMaxScaler()
column_cels = feature_names

x = data.loc[:,column_cels]
y = data['Crop Yield']

x = pd.DataFrame(data=min_max_scaller.fit_transform(x), columns=column_cels)
fig, axs = plt.subplots(ncols=2, nrows=6, figsize=(20, 20))
index = 0
axs = axs.flatten()

for i, k in enumerate(column_cels):
  sns.regplot(y=y, x=x[k], ax=axs[i])

plt.tight_layout()

# %%
# splitting Training and Testing data

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=5)

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

decision_tree = DecisionTreeRegressor(random_state=0)

decision_tree.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
decision_tree_pred = decision_tree.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error

metric_eval = {}

mse = mean_squared_error(y_test, decision_tree_pred)
rmse = np.sqrt(mse)
metric_eval['DecisionTree'] = rmse

# %% [markdown]
# Ada Boost

# %%
from sklearn.ensemble import AdaBoostRegressor

adaboost = AdaBoostRegressor()

adaboost.fit(x_train, y_train)
# Out:
# AdaBoostRegressor()

# %%
ada_pred = adaboost.predict(x_test)

# %%
mse = mean_squared_error(y_test, ada_pred)
rmse = np.sqrt(mse)

metric_eval['AdaBoost'] = rmse

# %% [markdown]
# EXTRA TREE

# %%
from sklearn.tree import ExtraTreeRegressor

extratree = ExtraTreeRegressor()

extratree.fit(x_train, y_train)
# Out:
# ExtraTreeRegressor()

# %%
extra_pred = extratree.predict(x_test)

# %%
mse = mean_squared_error(y_test, extra_pred)
rmse = np.sqrt(mse)

metric_eval['ExtraTree'] = rmse

# %% [markdown]
# RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestRegressor

random_forest = RandomForestRegressor()

random_forest.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
random_pred = random_forest.predict(x_test)

# %%
mse = mean_squared_error(y_test, random_pred)
rmse = np.sqrt(mse)

metric_eval['RandomForest'] = rmse

# %% [markdown]
# GRADIENBOOSTING

# %%
from sklearn.ensemble import GradientBoostingRegressor

grad_model = GradientBoostingRegressor()

grad_model.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
grad_pred = grad_model.predict(x_test)

# %%
mse = mean_squared_error(y_test, grad_pred)
rmse = np.sqrt(mse)

metric_eval['GradientBoosting'] = rmse

# %% [markdown]
# ANN

# %%
from tensorflow.python.keras.models import sequential
from tensorflow.python.keras.layers import Dense
from tensorflow.python.keras import regularizers

reg = regularizers.l2(0.01)

model = sequential.Sequential()

model.add(Dense(32, input_shape=(12,), activation='relu', kernel_regularizer=reg))
model.add(Dense(8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='relu'))

# %%
model.compile(optimizer='SGD', loss=['mean_squared_error'])
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_48 (Dense)             (None, 32)                416
# _________________________________________________________________
# dense_49 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dense_50 (Dense)             (None, 8)                 72
# _________________________________________________________________
# dense_51 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 761
# Trainable params: 761
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_result = model.fit(x_train, y_train, epochs=500, batch_size=20, validation_data=(x_test, y_test), verbose=1)
# Out:
# Epoch 1/500
# 2/2 [==============================] - 0s 136ms/step - loss: 130.7927 - val_loss: 64.8870
# Epoch 2/500
# 2/2 [==============================] - 0s 27ms/step - loss: 48.5376 - val_loss: 127.3916
# Epoch 3/500
# 2/2 [==============================] - 0s 80ms/step - loss: 115.6340 - val_loss: 60.6421
# Epoch 4/500
# 2/2 [==============================] - 0s 29ms/step - loss: 38.2328 - val_loss: 12.3276
# Epoch 5/500
# 2/2 [==============================] - 0s 26ms/step - loss: 13.1391 - val_loss: 79.5694
# Epoch 6/500
# 2/2 [==============================] - 0s 24ms/step - loss: 59.7252 - val_loss: 10.3953
# Epoch 7/500
# 2/2 [==============================] - 0s 26ms/step - loss: 18.4182 - val_loss: 4.6505
# Epoch 8/500
# 2/2 [==============================] - 0s 27ms/step - loss: 6.6115 - val_loss: 11.7206
# Epoch 9/500
# 2/2 [==============================] - 0s 24ms/step - loss: 28.7347 - val_loss: 11.8137
# Epoch 10/500
# 2/2 [==============================] - 0s 29ms/step - loss: 7.9026 - val_loss: 14.3104
# Epoch 11/500
# 2/2 [==============================] - 0s 26ms/step - loss: 8.0386 - val_loss: 5.1615
# Epoch 12/500
# 2/2 [==============================] - 0s 29ms/step - loss: 5.4695 - val_loss: 22.2744
# Epoch 13/500
# 2/2 [==============================] - 0s 25ms/step - loss: 13.4182 - val_loss: 1.6834
# Epoch 14/500
# 2/2 [==============================] - 0s 27ms/step - loss: 1.1425 - val_loss: 2.3257
# Epoch 15/500
# 2/2 [==============================] - 0s 24ms/step - loss: 1.8055 - val_loss: 4.0529
# Epoch 16/500
# 2/2 [==============================] - 0s 26ms/step - loss: 2.1326 - val_loss: 1.2691
# Epoch 17/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.5952 - val_loss: 0.5763
# Epoch 18/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.5238 - val_loss: 0.5750
# Epoch 19/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.6113 - val_loss: 0.5194
# Epoch 20/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.6513 - val_loss: 0.6174
# Epoch 21/500
# 2/2 [==============================] - 0s 27ms/step - loss: 1.1544 - val_loss: 1.0179
# Epoch 22/500
# 2/2 [==============================] - 0s 23ms/step - loss: 1.7493 - val_loss: 1.0091
# Epoch 23/500
# 2/2 [==============================] - 0s 30ms/step - loss: 1.5511 - val_loss: 0.8686
# Epoch 24/500
# 2/2 [==============================] - 0s 27ms/step - loss: 1.0885 - val_loss: 0.5902
# Epoch 25/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.7724 - val_loss: 0.4386
# Epoch 26/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.3923 - val_loss: 0.2779
# Epoch 27/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2784 - val_loss: 0.3289
# Epoch 28/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2684 - val_loss: 0.2498
# Epoch 29/500
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2632 - val_loss: 0.3990
# Epoch 30/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.3497 - val_loss: 0.4071
# Epoch 31/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.3573 - val_loss: 0.4020
# Epoch 32/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.4099 - val_loss: 0.6367
# Epoch 33/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.4321 - val_loss: 0.2870
# Epoch 34/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2722 - val_loss: 0.2802
# Epoch 35/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2459 - val_loss: 0.2051
# Epoch 36/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2397 - val_loss: 0.2089
# Epoch 37/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2429 - val_loss: 0.2054
# Epoch 38/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2259 - val_loss: 0.2122
# Epoch 39/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2221 - val_loss: 0.1884
# Epoch 40/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2215 - val_loss: 0.2102
# Epoch 41/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2183 - val_loss: 0.1853
# Epoch 42/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2306 - val_loss: 0.1917
# Epoch 43/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2221 - val_loss: 0.1992
# Epoch 44/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2126 - val_loss: 0.1812
# Epoch 45/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.2113 - val_loss: 0.2089
# Epoch 46/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2158 - val_loss: 0.1894
# Epoch 47/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2133 - val_loss: 0.2017
# Epoch 48/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2616 - val_loss: 0.1887
# Epoch 49/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2443 - val_loss: 0.1867
# Epoch 50/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2250 - val_loss: 0.1755
# Epoch 51/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2174 - val_loss: 0.1806
# Epoch 52/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.2526 - val_loss: 0.2324
# Epoch 53/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.3639 - val_loss: 0.3055
# Epoch 54/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.3565 - val_loss: 0.2072
# Epoch 55/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2475 - val_loss: 0.1829
# Epoch 56/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1983 - val_loss: 0.2304
# Epoch 57/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2089 - val_loss: 0.1729
# Epoch 58/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1949 - val_loss: 0.1824
# Epoch 59/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2083 - val_loss: 0.2424
# Epoch 60/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2208 - val_loss: 0.1808
# Epoch 61/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1932 - val_loss: 0.1745
# Epoch 62/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.2061 - val_loss: 0.1734
# Epoch 63/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1929 - val_loss: 0.1942
# Epoch 64/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2042 - val_loss: 0.1986
# Epoch 65/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2122 - val_loss: 0.2251
# Epoch 66/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2241 - val_loss: 0.2083
# Epoch 67/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2168 - val_loss: 0.2182
# Epoch 68/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2488 - val_loss: 0.3058
# Epoch 69/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2440 - val_loss: 0.1759
# Epoch 70/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1893 - val_loss: 0.1851
# Epoch 71/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.2086 - val_loss: 0.2546
# Epoch 72/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2416 - val_loss: 0.2191
# Epoch 73/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1962 - val_loss: 0.1701
# Epoch 74/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1859 - val_loss: 0.2077
# Epoch 75/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1946 - val_loss: 0.1714
# Epoch 76/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1842 - val_loss: 0.1697
# Epoch 77/500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1901 - val_loss: 0.1693
# Epoch 78/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1843 - val_loss: 0.1705
# Epoch 79/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1818 - val_loss: 0.1755
# Epoch 80/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1823 - val_loss: 0.1729
# Epoch 81/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1882 - val_loss: 0.2127
# Epoch 82/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.2064 - val_loss: 0.1928
# Epoch 83/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1850 - val_loss: 0.1686
# Epoch 84/500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1821 - val_loss: 0.1719
# Epoch 85/500
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1931 - val_loss: 0.1677
# Epoch 86/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1832 - val_loss: 0.1661
# Epoch 87/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1778 - val_loss: 0.1880
# Epoch 88/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1836 - val_loss: 0.1714
# Epoch 89/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1780 - val_loss: 0.1760
# Epoch 90/500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1762 - val_loss: 0.1661
# Epoch 91/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1874 - val_loss: 0.1718
# Epoch 92/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1996 - val_loss: 0.1738
# Epoch 93/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.2119 - val_loss: 0.1811
# Epoch 94/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.2305 - val_loss: 0.1975
# Epoch 95/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.2033 - val_loss: 0.1641
# Epoch 96/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1867 - val_loss: 0.1923
# Epoch 97/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2291 - val_loss: 0.1742
# Epoch 98/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.2128 - val_loss: 0.1842
# Epoch 99/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2046 - val_loss: 0.1641
# Epoch 100/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1813 - val_loss: 0.1620
# Epoch 101/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1719 - val_loss: 0.1678
# Epoch 102/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1733 - val_loss: 0.1825
# Epoch 103/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1744 - val_loss: 0.1661
# Epoch 104/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1693 - val_loss: 0.1620
# Epoch 105/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1697 - val_loss: 0.1644
# Epoch 106/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1689 - val_loss: 0.1707
# Epoch 107/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1692 - val_loss: 0.1645
# Epoch 108/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1677 - val_loss: 0.1626
# Epoch 109/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1674 - val_loss: 0.1654
# Epoch 110/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1702 - val_loss: 0.1835
# Epoch 111/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1746 - val_loss: 0.1700
# Epoch 112/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1682 - val_loss: 0.1677
# Epoch 113/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1687 - val_loss: 0.1748
# Epoch 114/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1703 - val_loss: 0.1708
# Epoch 115/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1660 - val_loss: 0.1610
# Epoch 116/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1699 - val_loss: 0.1644
# Epoch 117/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1872 - val_loss: 0.1704
# Epoch 118/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1785 - val_loss: 0.1609
# Epoch 119/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1651 - val_loss: 0.1597
# Epoch 120/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1666 - val_loss: 0.1597
# Epoch 121/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1637 - val_loss: 0.1640
# Epoch 122/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1629 - val_loss: 0.1604
# Epoch 123/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1646 - val_loss: 0.1597
# Epoch 124/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1633 - val_loss: 0.1687
# Epoch 125/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1660 - val_loss: 0.1726
# Epoch 126/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1652 - val_loss: 0.1644
# Epoch 127/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1659 - val_loss: 0.1837
# Epoch 128/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1734 - val_loss: 0.1750
# Epoch 129/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1654 - val_loss: 0.1640
# Epoch 130/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1608 - val_loss: 0.1584
# Epoch 131/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1651 - val_loss: 0.1583
# Epoch 132/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1628 - val_loss: 0.1588
# Epoch 133/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1600 - val_loss: 0.1700
# Epoch 134/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1605 - val_loss: 0.1583
# Epoch 135/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1604 - val_loss: 0.1578
# Epoch 136/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1603 - val_loss: 0.1578
# Epoch 137/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1595 - val_loss: 0.1575
# Epoch 138/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1594 - val_loss: 0.1577
# Epoch 139/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1589 - val_loss: 0.1570
# Epoch 140/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1645 - val_loss: 0.1621
# Epoch 141/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1715 - val_loss: 0.1567
# Epoch 142/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1607 - val_loss: 0.1570
# Epoch 143/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1589 - val_loss: 0.1563
# Epoch 144/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1598 - val_loss: 0.1563
# Epoch 145/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1577 - val_loss: 0.1836
# Epoch 146/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1643 - val_loss: 0.1598
# Epoch 147/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1563 - val_loss: 0.1555
# Epoch 148/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1561 - val_loss: 0.1730
# Epoch 149/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1582 - val_loss: 0.1559
# Epoch 150/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1555 - val_loss: 0.1567
# Epoch 151/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1561 - val_loss: 0.1710
# Epoch 152/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1601 - val_loss: 0.1624
# Epoch 153/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1585 - val_loss: 0.1719
# Epoch 154/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1555 - val_loss: 0.1548
# Epoch 155/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1573 - val_loss: 0.1554
# Epoch 156/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1590 - val_loss: 0.1603
# Epoch 157/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1635 - val_loss: 0.1555
# Epoch 158/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1533 - val_loss: 0.1573
# Epoch 159/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1543 - val_loss: 0.1652
# Epoch 160/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1544 - val_loss: 0.1554
# Epoch 161/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1526 - val_loss: 0.1557
# Epoch 162/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1525 - val_loss: 0.1536
# Epoch 163/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1532 - val_loss: 0.1758
# Epoch 164/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1636 - val_loss: 0.1703
# Epoch 165/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1572 - val_loss: 0.1596
# Epoch 166/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1523 - val_loss: 0.1555
# Epoch 167/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1513 - val_loss: 0.1556
# Epoch 168/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1511 - val_loss: 0.1537
# Epoch 169/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1509 - val_loss: 0.1544
# Epoch 170/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1509 - val_loss: 0.1598
# Epoch 171/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1507 - val_loss: 0.1518
# Epoch 172/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1530 - val_loss: 0.1515
# Epoch 173/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1523 - val_loss: 0.1520
# Epoch 174/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1503 - val_loss: 0.1535
# Epoch 175/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1498 - val_loss: 0.1585
# Epoch 176/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1504 - val_loss: 0.1555
# Epoch 177/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1505 - val_loss: 0.1529
# Epoch 178/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1602 - val_loss: 0.1512
# Epoch 179/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1541 - val_loss: 0.1505
# Epoch 180/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1510 - val_loss: 0.1508
# Epoch 181/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1485 - val_loss: 0.1574
# Epoch 182/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1507 - val_loss: 0.1622
# Epoch 183/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1484 - val_loss: 0.1509
# Epoch 184/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1537 - val_loss: 0.1498
# Epoch 185/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1488 - val_loss: 0.1516
# Epoch 186/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1475 - val_loss: 0.1512
# Epoch 187/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1472 - val_loss: 0.1545
# Epoch 188/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1484 - val_loss: 0.1521
# Epoch 189/500
# 2/2 [==============================] - 0s 74ms/step - loss: 0.1531 - val_loss: 0.1508
# Epoch 190/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1478 - val_loss: 0.1491
# Epoch 191/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1515 - val_loss: 0.1492
# Epoch 192/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1520 - val_loss: 0.1489
# Epoch 193/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1497 - val_loss: 0.1488
# Epoch 194/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1482 - val_loss: 0.1484
# Epoch 195/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1509 - val_loss: 0.1490
# Epoch 196/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1482 - val_loss: 0.1522
# Epoch 197/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1463 - val_loss: 0.1490
# Epoch 198/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1578 - val_loss: 0.1525
# Epoch 199/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1615 - val_loss: 0.1494
# Epoch 200/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1516 - val_loss: 0.1480
# Epoch 201/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1448 - val_loss: 0.1589
# Epoch 202/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1492 - val_loss: 0.1621
# Epoch 203/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1551 - val_loss: 0.1759
# Epoch 204/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1555 - val_loss: 0.1569
# Epoch 205/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1485 - val_loss: 0.1636
# Epoch 206/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1453 - val_loss: 0.1467
# Epoch 207/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1475 - val_loss: 0.1470
# Epoch 208/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1446 - val_loss: 0.1562
# Epoch 209/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1436 - val_loss: 0.1466
# Epoch 210/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1435 - val_loss: 0.1510
# Epoch 211/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1433 - val_loss: 0.1514
# Epoch 212/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1454 - val_loss: 0.1637
# Epoch 213/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1467 - val_loss: 0.1501
# Epoch 214/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1424 - val_loss: 0.1463
# Epoch 215/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1427 - val_loss: 0.1478
# Epoch 216/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1421 - val_loss: 0.1496
# Epoch 217/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1419 - val_loss: 0.1462
# Epoch 218/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1422 - val_loss: 0.1602
# Epoch 219/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1428 - val_loss: 0.1451
# Epoch 220/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1437 - val_loss: 0.1452
# Epoch 221/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1421 - val_loss: 0.1463
# Epoch 222/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1413 - val_loss: 0.1541
# Epoch 223/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1438 - val_loss: 0.1544
# Epoch 224/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1435 - val_loss: 0.1530
# Epoch 225/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1435 - val_loss: 0.1542
# Epoch 226/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1418 - val_loss: 0.1470
# Epoch 227/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1406 - val_loss: 0.1442
# Epoch 228/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1410 - val_loss: 0.1456
# Epoch 229/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1401 - val_loss: 0.1468
# Epoch 230/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1400 - val_loss: 0.1477
# Epoch 231/500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1404 - val_loss: 0.1514
# Epoch 232/500
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1412 - val_loss: 0.1497
# Epoch 233/500
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1437 - val_loss: 0.1659
# Epoch 234/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1486 - val_loss: 0.1545
# Epoch 235/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1409 - val_loss: 0.1463
# Epoch 236/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1390 - val_loss: 0.1445
# Epoch 237/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1391 - val_loss: 0.1439
# Epoch 238/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1390 - val_loss: 0.1441
# Epoch 239/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1388 - val_loss: 0.1438
# Epoch 240/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1387 - val_loss: 0.1434
# Epoch 241/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1384 - val_loss: 0.1453
# Epoch 242/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1381 - val_loss: 0.1450
# Epoch 243/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1380 - val_loss: 0.1454
# Epoch 244/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1379 - val_loss: 0.1428
# Epoch 245/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1378 - val_loss: 0.1470
# Epoch 246/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1378 - val_loss: 0.1439
# Epoch 247/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1382 - val_loss: 0.1545
# Epoch 248/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1417 - val_loss: 0.1506
# Epoch 249/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1376 - val_loss: 0.1415
# Epoch 250/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1390 - val_loss: 0.1411
# Epoch 251/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1374 - val_loss: 0.1464
# Epoch 252/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1376 - val_loss: 0.1475
# Epoch 253/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1370 - val_loss: 0.1430
# Epoch 254/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1365 - val_loss: 0.1433
# Epoch 255/500
# 2/2 [==============================] - 0s 21ms/step - loss: 0.1363 - val_loss: 0.1421
# Epoch 256/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1373 - val_loss: 0.1402
# Epoch 257/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1372 - val_loss: 0.1444
# Epoch 258/500
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1366 - val_loss: 0.1472
# Epoch 259/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1360 - val_loss: 0.1406
# Epoch 260/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1361 - val_loss: 0.1413
# Epoch 261/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1358 - val_loss: 0.1408
# Epoch 262/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1356 - val_loss: 0.1417
# Epoch 263/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1352 - val_loss: 0.1415
# Epoch 264/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1351 - val_loss: 0.1416
# Epoch 265/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1349 - val_loss: 0.1417
# Epoch 266/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1348 - val_loss: 0.1412
# Epoch 267/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1347 - val_loss: 0.1404
# Epoch 268/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1352 - val_loss: 0.1389
# Epoch 269/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1359 - val_loss: 0.1391
# Epoch 270/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1348 - val_loss: 0.1406
# Epoch 271/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1343 - val_loss: 0.1448
# Epoch 272/500
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1349 - val_loss: 0.1436
# Epoch 273/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1343 - val_loss: 0.1419
# Epoch 274/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1338 - val_loss: 0.1383
# Epoch 275/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1338 - val_loss: 0.1446
# Epoch 276/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1345 - val_loss: 0.1432
# Epoch 277/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1335 - val_loss: 0.1390
# Epoch 278/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1332 - val_loss: 0.1414
# Epoch 279/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1332 - val_loss: 0.1408
# Epoch 280/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1337 - val_loss: 0.1467
# Epoch 281/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1346 - val_loss: 0.1418
# Epoch 282/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1340 - val_loss: 0.1475
# Epoch 283/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1334 - val_loss: 0.1375
# Epoch 284/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1341 - val_loss: 0.1366
# Epoch 285/500
# 2/2 [==============================] - 0s 63ms/step - loss: 0.1328 - val_loss: 0.1449
# Epoch 286/500
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1344 - val_loss: 0.1455
# Epoch 287/500
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1324 - val_loss: 0.1362
# Epoch 288/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1333 - val_loss: 0.1384
# Epoch 289/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1321 - val_loss: 0.1364
# Epoch 290/500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1321 - val_loss: 0.1503
# Epoch 291/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1340 - val_loss: 0.1379
# Epoch 292/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1315 - val_loss: 0.1395
# Epoch 293/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1314 - val_loss: 0.1389
# Epoch 294/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1314 - val_loss: 0.1356
# Epoch 295/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1320 - val_loss: 0.1377
# Epoch 296/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1311 - val_loss: 0.1420
# Epoch 297/500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1313 - val_loss: 0.1375
# Epoch 298/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1308 - val_loss: 0.1398
# Epoch 299/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1308 - val_loss: 0.1376
# Epoch 300/500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1306 - val_loss: 0.1356
# Epoch 301/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1312 - val_loss: 0.1353
# Epoch 302/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1312 - val_loss: 0.1352
# Epoch 303/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1313 - val_loss: 0.1346
# Epoch 304/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1313 - val_loss: 0.1351
# Epoch 305/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1300 - val_loss: 0.1410
# Epoch 306/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1304 - val_loss: 0.1377
# Epoch 307/500
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1308 - val_loss: 0.1460
# Epoch 308/500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1328 - val_loss: 0.1414
# Epoch 309/500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1311 - val_loss: 0.1411
# Epoch 310/500
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1302 - val_loss: 0.1375
# Epoch 311/500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1292 - val_loss: 0.1352
# Epoch 312/500
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1295 - val_loss: 0.1344
# Epoch 313/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1301 - val_loss: 0.1337
# Epoch 314/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1295 - val_loss: 0.1362
# Epoch 315/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1287 - val_loss: 0.1353
# Epoch 316/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1286 - val_loss: 0.1359
# Epoch 317/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1291 - val_loss: 0.1330
# Epoch 318/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1302 - val_loss: 0.1349
# Epoch 319/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1292 - val_loss: 0.1481
# Epoch 320/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1367 - val_loss: 0.1527
# Epoch 321/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1345 - val_loss: 0.1395
# Epoch 322/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1302 - val_loss: 0.1439
# Epoch 323/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1295 - val_loss: 0.1348
# Epoch 324/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1278 - val_loss: 0.1387
# Epoch 325/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1277 - val_loss: 0.1323
# Epoch 326/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1285 - val_loss: 0.1334
# Epoch 327/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1275 - val_loss: 0.1339
# Epoch 328/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1278 - val_loss: 0.1440
# Epoch 329/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1328 - val_loss: 0.1464
# Epoch 330/500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1284 - val_loss: 0.1317
# Epoch 331/500
# 2/2 [==============================] - 0s 21ms/step - loss: 0.1275 - val_loss: 0.1352
# Epoch 332/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1268 - val_loss: 0.1337
# Epoch 333/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1273 - val_loss: 0.1312
# Epoch 334/500
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1276 - val_loss: 0.1354
# Epoch 335/500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1269 - val_loss: 0.1365
# Epoch 336/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1265 - val_loss: 0.1329
# Epoch 337/500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1267 - val_loss: 0.1416
# Epoch 338/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1295 - val_loss: 0.1396
# Epoch 339/500
# 2/2 [==============================] - 0s 78ms/step - loss: 0.1281 - val_loss: 0.1382
# Epoch 340/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1264 - val_loss: 0.1325
# Epoch 341/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1258 - val_loss: 0.1361
# Epoch 342/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1258 - val_loss: 0.1316
# Epoch 343/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1260 - val_loss: 0.1308
# Epoch 344/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1260 - val_loss: 0.1314
# Epoch 345/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1255 - val_loss: 0.1316
# Epoch 346/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1257 - val_loss: 0.1300
# Epoch 347/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1277 - val_loss: 0.1297
# Epoch 348/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1288 - val_loss: 0.1296
# Epoch 349/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1263 - val_loss: 0.1311
# Epoch 350/500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1248 - val_loss: 0.1330
# Epoch 351/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1249 - val_loss: 0.1345
# Epoch 352/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1247 - val_loss: 0.1311
# Epoch 353/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1245 - val_loss: 0.1347
# Epoch 354/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1250 - val_loss: 0.1340
# Epoch 355/500
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1243 - val_loss: 0.1295
# Epoch 356/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1245 - val_loss: 0.1306
# Epoch 357/500
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1240 - val_loss: 0.1310
# Epoch 358/500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1239 - val_loss: 0.1323
# Epoch 359/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1240 - val_loss: 0.1284
# Epoch 360/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1242 - val_loss: 0.1330
# Epoch 361/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1238 - val_loss: 0.1281
# Epoch 362/500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1245 - val_loss: 0.1317
# Epoch 363/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1235 - val_loss: 0.1315
# Epoch 364/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1233 - val_loss: 0.1288
# Epoch 365/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1234 - val_loss: 0.1297
# Epoch 366/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1232 - val_loss: 0.1292
# Epoch 367/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1232 - val_loss: 0.1289
# Epoch 368/500
# 2/2 [==============================] - 0s 79ms/step - loss: 0.1230 - val_loss: 0.1295
# Epoch 369/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1227 - val_loss: 0.1314
# Epoch 370/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1233 - val_loss: 0.1348
# Epoch 371/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1234 - val_loss: 0.1302
# Epoch 372/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1224 - val_loss: 0.1303
# Epoch 373/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1223 - val_loss: 0.1295
# Epoch 374/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1227 - val_loss: 0.1360
# Epoch 375/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1230 - val_loss: 0.1285
# Epoch 376/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1223 - val_loss: 0.1275
# Epoch 377/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1220 - val_loss: 0.1317
# Epoch 378/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1221 - val_loss: 0.1292
# Epoch 379/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1218 - val_loss: 0.1305
# Epoch 380/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1216 - val_loss: 0.1269
# Epoch 381/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1217 - val_loss: 0.1295
# Epoch 382/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1218 - val_loss: 0.1329
# Epoch 383/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1216 - val_loss: 0.1271
# Epoch 384/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1213 - val_loss: 0.1280
# Epoch 385/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1211 - val_loss: 0.1299
# Epoch 386/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1225 - val_loss: 0.1381
# Epoch 387/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1242 - val_loss: 0.1317
# Epoch 388/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1213 - val_loss: 0.1283
# Epoch 389/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1208 - val_loss: 0.1256
# Epoch 390/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1218 - val_loss: 0.1255
# Epoch 391/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1212 - val_loss: 0.1263
# Epoch 392/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1210 - val_loss: 0.1253
# Epoch 393/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1205 - val_loss: 0.1297
# Epoch 394/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1206 - val_loss: 0.1293
# Epoch 395/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1201 - val_loss: 0.1248
# Epoch 396/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1202 - val_loss: 0.1312
# Epoch 397/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1219 - val_loss: 0.1345
# Epoch 398/500
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1212 - val_loss: 0.1272
# Epoch 399/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1201 - val_loss: 0.1242
# Epoch 400/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1212 - val_loss: 0.1254
# Epoch 401/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1195 - val_loss: 0.1282
# Epoch 402/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1201 - val_loss: 0.1315
# Epoch 403/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1195 - val_loss: 0.1239
# Epoch 404/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1220 - val_loss: 0.1237
# Epoch 405/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1217 - val_loss: 0.1239
# Epoch 406/500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1210 - val_loss: 0.1235
# Epoch 407/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1200 - val_loss: 0.1253
# Epoch 408/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1188 - val_loss: 0.1252
# Epoch 409/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1187 - val_loss: 0.1259
# Epoch 410/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1189 - val_loss: 0.1308
# Epoch 411/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1207 - val_loss: 0.1320
# Epoch 412/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1219 - val_loss: 0.1352
# Epoch 413/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1195 - val_loss: 0.1235
# Epoch 414/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1192 - val_loss: 0.1232
# Epoch 415/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1184 - val_loss: 0.1259
# Epoch 416/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1180 - val_loss: 0.1250
# Epoch 417/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1179 - val_loss: 0.1244
# Epoch 418/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1178 - val_loss: 0.1262
# Epoch 419/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1183 - val_loss: 0.1302
# Epoch 420/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1195 - val_loss: 0.1293
# Epoch 421/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1191 - val_loss: 0.1291
# Epoch 422/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1186 - val_loss: 0.1270
# Epoch 423/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1176 - val_loss: 0.1248
# Epoch 424/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1174 - val_loss: 0.1270
# Epoch 425/500
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1175 - val_loss: 0.1251
# Epoch 426/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1171 - val_loss: 0.1256
# Epoch 427/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1169 - val_loss: 0.1235
# Epoch 428/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1169 - val_loss: 0.1227
# Epoch 429/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1171 - val_loss: 0.1219
# Epoch 430/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1169 - val_loss: 0.1241
# Epoch 431/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1165 - val_loss: 0.1229
# Epoch 432/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1168 - val_loss: 0.1214
# Epoch 433/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1177 - val_loss: 0.1212
# Epoch 434/500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1167 - val_loss: 0.1235
# Epoch 435/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1162 - val_loss: 0.1249
# Epoch 436/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1164 - val_loss: 0.1257
# Epoch 437/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1162 - val_loss: 0.1236
# Epoch 438/500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1159 - val_loss: 0.1240
# Epoch 439/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1158 - val_loss: 0.1209
# Epoch 440/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1159 - val_loss: 0.1232
# Epoch 441/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1155 - val_loss: 0.1227
# Epoch 442/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1154 - val_loss: 0.1237
# Epoch 443/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1154 - val_loss: 0.1219
# Epoch 444/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1153 - val_loss: 0.1212
# Epoch 445/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1152 - val_loss: 0.1222
# Epoch 446/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1151 - val_loss: 0.1213
# Epoch 447/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1150 - val_loss: 0.1218
# Epoch 448/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1151 - val_loss: 0.1264
# Epoch 449/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1165 - val_loss: 0.1271
# Epoch 450/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1150 - val_loss: 0.1199
# Epoch 451/500
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1148 - val_loss: 0.1229
# Epoch 452/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1149 - val_loss: 0.1252
# Epoch 453/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1147 - val_loss: 0.1208
# Epoch 454/500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1153 - val_loss: 0.1190
# Epoch 455/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1152 - val_loss: 0.1234
# Epoch 456/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1145 - val_loss: 0.1228
# Epoch 457/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1142 - val_loss: 0.1223
# Epoch 458/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1142 - val_loss: 0.1239
# Epoch 459/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1143 - val_loss: 0.1221
# Epoch 460/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1137 - val_loss: 0.1204
# Epoch 461/500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1138 - val_loss: 0.1194
# Epoch 462/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1136 - val_loss: 0.1252
# Epoch 463/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1141 - val_loss: 0.1206
# Epoch 464/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1133 - val_loss: 0.1199
# Epoch 465/500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1133 - val_loss: 0.1209
# Epoch 466/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1135 - val_loss: 0.1244
# Epoch 467/500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1138 - val_loss: 0.1213
# Epoch 468/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1132 - val_loss: 0.1224
# Epoch 469/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1137 - val_loss: 0.1241
# Epoch 470/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1152 - val_loss: 0.1293
# Epoch 471/500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1147 - val_loss: 0.1202
# Epoch 472/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1132 - val_loss: 0.1174
# Epoch 473/500
# 2/2 [==============================] - 0s 66ms/step - loss: 0.1143 - val_loss: 0.1188
# Epoch 474/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1128 - val_loss: 0.1176
# Epoch 475/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1142 - val_loss: 0.1171
# Epoch 476/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1143 - val_loss: 0.1177
# Epoch 477/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1138 - val_loss: 0.1169
# Epoch 478/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1153 - val_loss: 0.1169
# Epoch 479/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1130 - val_loss: 0.1178
# Epoch 480/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1125 - val_loss: 0.1169
# Epoch 481/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1120 - val_loss: 0.1207
# Epoch 482/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1118 - val_loss: 0.1181
# Epoch 483/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1116 - val_loss: 0.1187
# Epoch 484/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1119 - val_loss: 0.1237
# Epoch 485/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1140 - val_loss: 0.1265
# Epoch 486/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1143 - val_loss: 0.1233
# Epoch 487/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1124 - val_loss: 0.1198
# Epoch 488/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1114 - val_loss: 0.1197
# Epoch 489/500
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1111 - val_loss: 0.1175
# Epoch 490/500
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1110 - val_loss: 0.1183
# Epoch 491/500
# 2/2 [==============================] - 0s 23ms/step - loss: 0.1109 - val_loss: 0.1190
# Epoch 492/500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1108 - val_loss: 0.1164
# Epoch 493/500
# 2/2 [==============================] - 0s 22ms/step - loss: 0.1115 - val_loss: 0.1158
# Epoch 494/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1109 - val_loss: 0.1189
# Epoch 495/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1105 - val_loss: 0.1171
# Epoch 496/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1107 - val_loss: 0.1229
# Epoch 497/500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1115 - val_loss: 0.1186
# Epoch 498/500
# 2/2 [==============================] - 0s 59ms/step - loss: 0.1103 - val_loss: 0.1177
# Epoch 499/500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1103 - val_loss: 0.1201
# Epoch 500/500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.1102 - val_loss: 0.1160

# %%
plt.figure(figsize=(20, 5))
plt.plot(model_result.history['loss'])
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend(['Training MSE'])
plt.title('Learning Curve')
# Out:
# Text(0.5, 1.0, 'Learning Curve')

# %%
from tensorflow.python.keras.losses import MeanSquaredError
from tensorflow.python.keras.metrics import RootMeanSquaredError

mse = MeanSquaredError()
rmse = RootMeanSquaredError()

ann_predict = model.predict(x_test)

predict_mse = mse(y_test, ann_predict).numpy()
predict_rmse = rmse(y_test, ann_predict).numpy()

metric_eval['ANN'] = predict_rmse

# %% [markdown]
# METRIC

# %%
metric_df = pd.DataFrame(data=metric_eval, index=['RMSE'])
metric_df
# Out:
#       DecisionTree  AdaBoost  ExtraTree  RandomForest  GradientBoosting  \
# RMSE      0.145098  0.118302    0.14299      0.107509          0.113218
#
#            ANN
# RMSE  0.092884

# %%
plt.figure(figsize=(15, 10))
ax = sns.barplot(data=metric_df)

plt.xlabel('Model')
plt.ylabel('RMSE')
plt.title('Evaluasi Model dan Dataset* Lower better')
# Out:
# Text(0.5, 1.0, 'Evaluasi Model dan Dataset* Lower better')
